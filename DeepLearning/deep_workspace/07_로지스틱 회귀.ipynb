# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터
x_data = [2, 4, 6, 8, 10, 12, 14]
y_data = [0, 0, 0, 1, 1, 1, 1]

print(x_data)
print(y_data)
# Out:
# [2, 4, 6, 8, 10, 12, 14]
# [0, 0, 0, 1, 1, 1, 1]

# %%
# 그래프로 나타내기
plt.scatter(x_data, y_data)
plt.show()

# %%
# a와 b의 값
a = 0
b = 0

# %%
# 학습률
lr = 0.05

# %%
# 시그모이드 함수
def sigmoid(x) :
    return 1 / (1 + np.e ** (-x))

# %%
# 반복 횟수
epochs = 20001

# %%
# ndarray 생성
x_data2 = np.array(x_data)
y_data2 = np.array(y_data)

print(x_data2)
print(y_data2)
# Out:
# [ 2  4  6  8 10 12 14]
# [0 0 0 1 1 1 1]

# %%
for i in range(epochs) :
    # 예측 결과를 가져온다.
    y_pred = sigmoid(a * x_data2 + b)
    # print(y_pred)
    
    # 오차를 계산한다.
    error = y_pred - y_data2
    # print(error)
    
    # a와 b에 대한 편미분을 수행한다.
    a_diff = (1 / len(x_data2)) * sum(x_data2 * error)
    b_diff = (1 / len(x_data2)) * sum(error)
    
    # print(a_diff)
    # print(b_diff)
    
    # a와 b의 값을 계산한다.
    a = a - lr * a_diff
    b = b - lr * b_diff
    
    # print(a)
    # print(b)
    
    if i % 1000 == 0 :
        print(f'epoch {i}, a : {a}, b : {b}')
        
        plt.scatter(x_data2, y_data2)
        # 그래프로 나타낼 x값의 범위
        x_range = (np.arange(0, 15, 0.1))
        plt.plot(x_range, np.array([sigmoid(a * x + b) for x in x_range]))
        plt.show()
# Out:
# epoch 0, a : 0.11428571428571428, b : 0.0035714285714285713
# epoch 1000, a : 0.6151287112349703, b : -3.9133983739489606
# epoch 2000, a : 0.8313428384390508, b : -5.517360229869611
# epoch 3000, a : 0.9807171236892178, b : -6.602697135651437
# epoch 4000, a : 1.098762709073372, b : -7.452122275824215
# epoch 5000, a : 1.1981720743892494, b : -8.163361627480453
# epoch 6000, a : 1.2850080434263396, b : -8.78228254291844
# epoch 7000, a : 1.3626705011689049, b : -9.334315933646755
# epoch 8000, a : 1.4332735838087856, b : -9.835146932440702
# epoch 9000, a : 1.4982309404136402, b : -10.295198164169562
# epoch 10000, a : 1.5585402774332098, b : -10.721788669600098
# epoch 11000, a : 1.6149357823675305, b : -11.120281942894279
# epoch 12000, a : 1.6679760062148674, b : -11.49474398748463
# epoch 13000, a : 1.718097555928892, b : -11.848343423161301
# epoch 14000, a : 1.7656494744958398, b : -12.183606635907614
# epoch 15000, a : 1.8109161274831242, b : -12.502587031026186
# epoch 16000, a : 1.8541329459088605, b : -12.806981096547139
# epoch 17000, a : 1.8954975630381712, b : -13.09821028261382
# epoch 18000, a : 1.9351778863046485, b : -13.377480200357068
# epoch 19000, a : 1.9733180733601767, b : -13.645824351055765
# epoch 20000, a : 2.0100430401197906, b : -13.904137045223084

# %%
y_pred = a * x_data2 + b
y_pred
# Out:
# array([-9.88405096, -5.86396488, -1.8438788 ,  2.17620728,  6.19629336,
#        10.21637944, 14.23646552])
