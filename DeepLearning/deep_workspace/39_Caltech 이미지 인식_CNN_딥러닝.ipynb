# %%
# 경고 메시지가 안나오게..
import warnings
warnings.filterwarnings('ignore')

# 기본
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno

# KFold
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 교차 검증 함수
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# 학습 데이터와 검증데이터로 나누는 함수
from sklearn.model_selection import train_test_split

# 데이터 전처리
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 하이퍼 파라미터 튜닝
from sklearn.model_selection import GridSearchCV

# 평가함수
from sklearn.metrics import accuracy_score

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# 군집
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift

# 차원축소
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# 딥러닝
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

from keras.utils import np_utils
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import LeakyReLU
from keras.layers import BatchNormalization
from keras.layers import Reshape
from keras.layers import UpSampling2D
from keras.layers import Input
from keras.models import Model

# 다중분류를 위한 핫-윈 인코더
from keras.utils import to_categorical

# 저장된 딥러닝 모델을 복구하는 함수
from keras.models import load_model

# epoch마다 모델을 저장하는 함수
from keras.callbacks import ModelCheckpoint

# 더이상 성능 향상이 이루어지지 않는다면 조기 중단시킬 수 있는 함수
from keras.callbacks import EarlyStopping

# 문장을 잘라준다.
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence 

# 이미지 생성자
from keras.preprocessing.image import ImageDataGenerator

# VGG16 모델(이미 학습이 완료되어 있는 이미지 인식 모델)
from keras.applications import VGG16

# 전처리, 활성 함수 셋팅
from keras import optimizers

# 저장
import pickle

# 시간 모듈
import time

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# gpu 사용 초기화 및 할당
gpus= tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
# 폴더 목록을 가져온다
import os

categories = list(os.walk('img/101_ObjectCategories'))[0][1]
categories
# Out:
# ['accordion',
#  'airplanes',
#  'anchor',
#  'ant',
#  'BACKGROUND_Google',
#  'barrel',
#  'bass',
#  'beaver',
#  'binocular',
#  'bonsai',
#  'brain',
#  'brontosaurus',
#  'buddha',
#  'butterfly',
#  'camera',
#  'cannon',
#  'car_side',
#  'ceiling_fan',
#  'cellphone',
#  'chair',
#  'chandelier',
#  'cougar_body',
#  'cougar_face',
#  'crab',
#  'crayfish',
#  'crocodile',
#  'crocodile_head',
#  'cup',
#  'dalmatian',
#  'dollar_bill',
#  'dolphin',
#  'dragonfly',
#  'electric_guitar',
#  'elephant',
#  'emu',
#  'euphonium',
#  'ewer',
#  'Faces',
#  'Faces_easy',
#  'ferry',
#  'flamingo',
#  'flamingo_head',
#  'garfield',
#  'gerenuk',
#  'gramophone',
#  'grand_piano',
#  'hawksbill',
#  'headphone',
#  'hedgehog',
#  'helicopter',
#  'ibis',
#  'inline_skate',
#  'joshua_tree',
#  'kangaroo',
#  'ketch',
#  'lamp',
#  'laptop',
#  'Leopards',
#  'llama',
#  'lobster',
#  'lotus',
#  'mandolin',
#  'mayfly',
#  'menorah',
#  'metronome',
#  'minaret',
#  'Motorbikes',
#  'nautilus',
#  'octopus',
#  'okapi',
#  'pagoda',
#  'panda',
#  'pigeon',
#  'pizza',
#  'platypus',
#  'pyramid',
#  'revolver',
#  'rhino',
#  'rooster',
#  'saxophone',
#  'schooner',
#  'scissors',
#  'scorpion',
#  'sea_horse',
#  'snoopy',
#  'soccer_ball',
#  'stapler',
#  'starfish',
#  'stegosaurus',
#  'stop_sign',
#  'strawberry',
#  'sunflower',
#  'tick',
#  'trilobite',
#  'umbrella',
#  'watch',
#  'water_lilly',
#  'wheelchair',
#  'wild_cat',
#  'windsor_chair',
#  'wrench',
#  'yin_yang']

# %%
# 이미지의 크기값
image_w = 64
image_h = 64

# %%
# 전처리 후 저장한 데이터를 읽어온다
X_train, X_test, y_train, y_test = np.load('img/caltech_obj_101.npy', allow_pickle=True)

# %%
# 데이터 정규화(색상 값을 0 ~ 1사이로 조정한다.)
X_train = X_train.astype('float') / 256
X_test = X_test.astype('float') / 256
print(X_train.shape)
print(X_test.shape)
# Out:
# (6858, 64, 64, 3)
# (2286, 64, 64, 3)

# %%
# 모델 구축하기
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), input_shape=X_train.shape[1:], padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=4))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, kernel_size=(3, 3)))
model.add(MaxPooling2D(pool_size=4))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(len(categories)))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 모델 저장 조건
modelpath = 'models/{epoch}-{val_loss}.hdf5'
callback1 = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
# 자동 중단 설정
callback2 = EarlyStopping(monitor='val_loss', patience=100)

# %%
# 학습한다
model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=1000, callbacks=[callback1, callback2])
# Out:
# Epoch 1/1000
# 215/215 [==============================] - 4s 8ms/step - loss: 4.1877 - accuracy: 0.1182 - val_loss: 3.1950 - val_accuracy: 0.3010
#
# Epoch 00001: val_loss improved from inf to 3.19504, saving model to models\1-3.195044994354248.hdf5
# Epoch 2/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 3.1139 - accuracy: 0.3293 - val_loss: 2.4686 - val_accuracy: 0.4431
#
# Epoch 00002: val_loss improved from 3.19504 to 2.46863, saving model to models\2-2.468625068664551.hdf5
# Epoch 3/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 2.3607 - accuracy: 0.4532 - val_loss: 1.9764 - val_accuracy: 0.5420
#
# Epoch 00003: val_loss improved from 2.46863 to 1.97643, saving model to models\3-1.9764264822006226.hdf5
# Epoch 4/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.9727 - accuracy: 0.5285 - val_loss: 1.8310 - val_accuracy: 0.5717
#
# Epoch 00004: val_loss improved from 1.97643 to 1.83103, saving model to models\4-1.8310256004333496.hdf5
# Epoch 5/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.6515 - accuracy: 0.5897 - val_loss: 1.6584 - val_accuracy: 0.6085
#
# Epoch 00005: val_loss improved from 1.83103 to 1.65845, saving model to models\5-1.6584473848342896.hdf5
# Epoch 6/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.5220 - accuracy: 0.6066 - val_loss: 1.5725 - val_accuracy: 0.6264
#
# Epoch 00006: val_loss improved from 1.65845 to 1.57254, saving model to models\6-1.572535753250122.hdf5
# Epoch 7/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.3202 - accuracy: 0.6516 - val_loss: 1.4897 - val_accuracy: 0.6483
#
# Epoch 00007: val_loss improved from 1.57254 to 1.48973, saving model to models\7-1.4897253513336182.hdf5
# Epoch 8/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.2022 - accuracy: 0.6800 - val_loss: 1.4535 - val_accuracy: 0.6522
#
# Epoch 00008: val_loss improved from 1.48973 to 1.45351, saving model to models\8-1.4535127878189087.hdf5
# Epoch 9/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 1.1021 - accuracy: 0.7002 - val_loss: 1.4189 - val_accuracy: 0.6636
#
# Epoch 00009: val_loss improved from 1.45351 to 1.41890, saving model to models\9-1.418897032737732.hdf5
# Epoch 10/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.9644 - accuracy: 0.7300 - val_loss: 1.4502 - val_accuracy: 0.6605
#
# Epoch 00010: val_loss did not improve from 1.41890
# Epoch 11/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.9269 - accuracy: 0.7429 - val_loss: 1.4022 - val_accuracy: 0.6741
#
# Epoch 00011: val_loss improved from 1.41890 to 1.40221, saving model to models\11-1.4022126197814941.hdf5
# Epoch 12/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.8170 - accuracy: 0.7710 - val_loss: 1.4663 - val_accuracy: 0.6649
#
# Epoch 00012: val_loss did not improve from 1.40221
# Epoch 13/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.7818 - accuracy: 0.7784 - val_loss: 1.4828 - val_accuracy: 0.6745
#
# Epoch 00013: val_loss did not improve from 1.40221
# Epoch 14/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.7088 - accuracy: 0.7912 - val_loss: 1.4317 - val_accuracy: 0.6732
#
# Epoch 00014: val_loss did not improve from 1.40221
# Epoch 15/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.6924 - accuracy: 0.7950 - val_loss: 1.4881 - val_accuracy: 0.6807
#
# Epoch 00015: val_loss did not improve from 1.40221
# Epoch 16/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.6495 - accuracy: 0.8081 - val_loss: 1.4730 - val_accuracy: 0.6776
#
# Epoch 00016: val_loss did not improve from 1.40221
# Epoch 17/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.5882 - accuracy: 0.8297 - val_loss: 1.4292 - val_accuracy: 0.6868
#
# Epoch 00017: val_loss did not improve from 1.40221
# Epoch 18/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.5336 - accuracy: 0.8412 - val_loss: 1.4280 - val_accuracy: 0.6855
#
# Epoch 00018: val_loss did not improve from 1.40221
# Epoch 19/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.5143 - accuracy: 0.8403 - val_loss: 1.4803 - val_accuracy: 0.6811
#
# Epoch 00019: val_loss did not improve from 1.40221
# Epoch 20/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.5267 - accuracy: 0.8437 - val_loss: 1.5507 - val_accuracy: 0.6859
#
# Epoch 00020: val_loss did not improve from 1.40221
# Epoch 21/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4632 - accuracy: 0.8678 - val_loss: 1.5584 - val_accuracy: 0.6859
#
# Epoch 00021: val_loss did not improve from 1.40221
# Epoch 22/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4432 - accuracy: 0.8627 - val_loss: 1.6355 - val_accuracy: 0.6864
#
# Epoch 00022: val_loss did not improve from 1.40221
# Epoch 23/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4425 - accuracy: 0.8688 - val_loss: 1.5882 - val_accuracy: 0.6850
#
# Epoch 00023: val_loss did not improve from 1.40221
# Epoch 24/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4237 - accuracy: 0.8697 - val_loss: 1.5694 - val_accuracy: 0.6885
#
# Epoch 00024: val_loss did not improve from 1.40221
# Epoch 25/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4165 - accuracy: 0.8692 - val_loss: 1.6783 - val_accuracy: 0.6899
#
# Epoch 00025: val_loss did not improve from 1.40221
# Epoch 26/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3793 - accuracy: 0.8855 - val_loss: 1.5888 - val_accuracy: 0.6885
#
# Epoch 00026: val_loss did not improve from 1.40221
# Epoch 27/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.4014 - accuracy: 0.8755 - val_loss: 1.6749 - val_accuracy: 0.6955
#
# Epoch 00027: val_loss did not improve from 1.40221
# Epoch 28/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3572 - accuracy: 0.8908 - val_loss: 1.6140 - val_accuracy: 0.6745
#
# Epoch 00028: val_loss did not improve from 1.40221
# Epoch 29/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3592 - accuracy: 0.8894 - val_loss: 1.6004 - val_accuracy: 0.6855
#
# Epoch 00029: val_loss did not improve from 1.40221
# Epoch 30/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3622 - accuracy: 0.8853 - val_loss: 1.8206 - val_accuracy: 0.6794
#
# Epoch 00030: val_loss did not improve from 1.40221
# Epoch 31/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3536 - accuracy: 0.8887 - val_loss: 1.9097 - val_accuracy: 0.6824
#
# Epoch 00031: val_loss did not improve from 1.40221
# Epoch 32/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3443 - accuracy: 0.8946 - val_loss: 1.6897 - val_accuracy: 0.6807
#
# Epoch 00032: val_loss did not improve from 1.40221
# Epoch 33/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3432 - accuracy: 0.8919 - val_loss: 1.9227 - val_accuracy: 0.6719
#
# Epoch 00033: val_loss did not improve from 1.40221
# Epoch 34/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3280 - accuracy: 0.9015 - val_loss: 1.7951 - val_accuracy: 0.6881
#
# Epoch 00034: val_loss did not improve from 1.40221
# Epoch 35/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3045 - accuracy: 0.9045 - val_loss: 1.7060 - val_accuracy: 0.6837
#
# Epoch 00035: val_loss did not improve from 1.40221
# Epoch 36/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2968 - accuracy: 0.9124 - val_loss: 1.7637 - val_accuracy: 0.6894
#
# Epoch 00036: val_loss did not improve from 1.40221
# Epoch 37/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3227 - accuracy: 0.9028 - val_loss: 1.8054 - val_accuracy: 0.6745
#
# Epoch 00037: val_loss did not improve from 1.40221
# Epoch 38/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.3227 - accuracy: 0.9063 - val_loss: 1.8634 - val_accuracy: 0.6955
#
# Epoch 00038: val_loss did not improve from 1.40221
# Epoch 39/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2908 - accuracy: 0.9115 - val_loss: 1.8093 - val_accuracy: 0.6969
#
# Epoch 00039: val_loss did not improve from 1.40221
# Epoch 40/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2766 - accuracy: 0.9139 - val_loss: 1.8193 - val_accuracy: 0.6885
#
# Epoch 00040: val_loss did not improve from 1.40221
# Epoch 41/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2901 - accuracy: 0.9142 - val_loss: 1.8146 - val_accuracy: 0.6785
#
# Epoch 00041: val_loss did not improve from 1.40221
# Epoch 42/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2753 - accuracy: 0.9120 - val_loss: 1.8101 - val_accuracy: 0.6934
#
# Epoch 00042: val_loss did not improve from 1.40221
# Epoch 43/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2854 - accuracy: 0.9117 - val_loss: 1.8750 - val_accuracy: 0.6929
#
# Epoch 00043: val_loss did not improve from 1.40221
# Epoch 44/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2782 - accuracy: 0.9123 - val_loss: 2.0404 - val_accuracy: 0.6864
#
# Epoch 00044: val_loss did not improve from 1.40221
# Epoch 45/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2655 - accuracy: 0.9213 - val_loss: 1.9000 - val_accuracy: 0.6829
#
# Epoch 00045: val_loss did not improve from 1.40221
# Epoch 46/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2881 - accuracy: 0.9121 - val_loss: 1.7782 - val_accuracy: 0.6811
#
# Epoch 00046: val_loss did not improve from 1.40221
# Epoch 47/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2848 - accuracy: 0.9181 - val_loss: 2.1032 - val_accuracy: 0.6811
#
# Epoch 00047: val_loss did not improve from 1.40221
# Epoch 48/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2477 - accuracy: 0.9264 - val_loss: 2.0742 - val_accuracy: 0.6837
#
# Epoch 00048: val_loss did not improve from 1.40221
# Epoch 49/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2623 - accuracy: 0.9213 - val_loss: 2.0426 - val_accuracy: 0.6767
#
# Epoch 00049: val_loss did not improve from 1.40221
# Epoch 50/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2357 - accuracy: 0.9321 - val_loss: 1.9640 - val_accuracy: 0.6903
#
# Epoch 00050: val_loss did not improve from 1.40221
# Epoch 51/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2790 - accuracy: 0.9118 - val_loss: 1.9430 - val_accuracy: 0.6969
#
# Epoch 00051: val_loss did not improve from 1.40221
# Epoch 52/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2604 - accuracy: 0.9168 - val_loss: 2.0031 - val_accuracy: 0.6916
#
# Epoch 00052: val_loss did not improve from 1.40221
# Epoch 53/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2741 - accuracy: 0.9148 - val_loss: 2.1099 - val_accuracy: 0.6920
#
# Epoch 00053: val_loss did not improve from 1.40221
# Epoch 54/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2237 - accuracy: 0.9352 - val_loss: 1.9267 - val_accuracy: 0.6807
#
# Epoch 00054: val_loss did not improve from 1.40221
# Epoch 55/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2752 - accuracy: 0.9185 - val_loss: 2.0091 - val_accuracy: 0.6903
#
# Epoch 00055: val_loss did not improve from 1.40221
# Epoch 56/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2661 - accuracy: 0.9205 - val_loss: 2.0896 - val_accuracy: 0.6872
#
# Epoch 00056: val_loss did not improve from 1.40221
# Epoch 57/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2321 - accuracy: 0.9250 - val_loss: 2.2269 - val_accuracy: 0.6842
#
# Epoch 00057: val_loss did not improve from 1.40221
# Epoch 58/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2598 - accuracy: 0.9238 - val_loss: 2.1430 - val_accuracy: 0.6859
#
# Epoch 00058: val_loss did not improve from 1.40221
# Epoch 59/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2580 - accuracy: 0.9215 - val_loss: 2.0463 - val_accuracy: 0.6947
#
# Epoch 00059: val_loss did not improve from 1.40221
# Epoch 60/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2464 - accuracy: 0.9221 - val_loss: 2.1425 - val_accuracy: 0.6960
#
# Epoch 00060: val_loss did not improve from 1.40221
# Epoch 61/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2411 - accuracy: 0.9234 - val_loss: 2.1997 - val_accuracy: 0.6789
#
# Epoch 00061: val_loss did not improve from 1.40221
# Epoch 62/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2453 - accuracy: 0.9235 - val_loss: 1.9393 - val_accuracy: 0.6890
#
# Epoch 00062: val_loss did not improve from 1.40221
# Epoch 63/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2398 - accuracy: 0.9277 - val_loss: 2.0856 - val_accuracy: 0.6881
#
# Epoch 00063: val_loss did not improve from 1.40221
# Epoch 64/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2282 - accuracy: 0.9293 - val_loss: 2.0790 - val_accuracy: 0.6890
#
# Epoch 00064: val_loss did not improve from 1.40221
# Epoch 65/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2488 - accuracy: 0.9239 - val_loss: 1.9126 - val_accuracy: 0.6947
#
# Epoch 00065: val_loss did not improve from 1.40221
# Epoch 66/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2486 - accuracy: 0.9244 - val_loss: 2.0846 - val_accuracy: 0.6929
#
# Epoch 00066: val_loss did not improve from 1.40221
# Epoch 67/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2439 - accuracy: 0.9288 - val_loss: 1.9451 - val_accuracy: 0.6899
#
# Epoch 00067: val_loss did not improve from 1.40221
# Epoch 68/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2418 - accuracy: 0.9263 - val_loss: 2.0674 - val_accuracy: 0.6925
#
# Epoch 00068: val_loss did not improve from 1.40221
# Epoch 69/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2219 - accuracy: 0.9366 - val_loss: 2.0594 - val_accuracy: 0.6894
#
# Epoch 00069: val_loss did not improve from 1.40221
# Epoch 70/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2048 - accuracy: 0.9373 - val_loss: 2.0707 - val_accuracy: 0.6907
#
# Epoch 00070: val_loss did not improve from 1.40221
# Epoch 71/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2235 - accuracy: 0.9340 - val_loss: 2.1246 - val_accuracy: 0.6899
#
# Epoch 00071: val_loss did not improve from 1.40221
# Epoch 72/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2205 - accuracy: 0.9318 - val_loss: 2.0858 - val_accuracy: 0.7008
#
# Epoch 00072: val_loss did not improve from 1.40221
# Epoch 73/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2542 - accuracy: 0.9248 - val_loss: 2.0721 - val_accuracy: 0.6842
#
# Epoch 00073: val_loss did not improve from 1.40221
# Epoch 74/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2419 - accuracy: 0.9313 - val_loss: 2.1370 - val_accuracy: 0.6955
#
# Epoch 00074: val_loss did not improve from 1.40221
# Epoch 75/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2140 - accuracy: 0.9335 - val_loss: 2.3662 - val_accuracy: 0.6947
#
# Epoch 00075: val_loss did not improve from 1.40221
# Epoch 76/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2294 - accuracy: 0.9335 - val_loss: 2.1551 - val_accuracy: 0.6868
#
# Epoch 00076: val_loss did not improve from 1.40221
# Epoch 77/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2090 - accuracy: 0.9323 - val_loss: 2.0761 - val_accuracy: 0.6872
#
# Epoch 00077: val_loss did not improve from 1.40221
# Epoch 78/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2258 - accuracy: 0.9352 - val_loss: 2.1971 - val_accuracy: 0.6833
#
# Epoch 00078: val_loss did not improve from 1.40221
# Epoch 79/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2189 - accuracy: 0.9343 - val_loss: 2.1678 - val_accuracy: 0.6689
#
# Epoch 00079: val_loss did not improve from 1.40221
# Epoch 80/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1954 - accuracy: 0.9402 - val_loss: 2.2614 - val_accuracy: 0.6885
#
# Epoch 00080: val_loss did not improve from 1.40221
# Epoch 81/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2172 - accuracy: 0.9357 - val_loss: 2.2056 - val_accuracy: 0.6942
# Epoch 00081: val_loss did not improve from 1.40221
# Epoch 82/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2030 - accuracy: 0.9332 - val_loss: 2.1477 - val_accuracy: 0.6925
#
# Epoch 00082: val_loss did not improve from 1.40221
# Epoch 83/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1952 - accuracy: 0.9442 - val_loss: 2.2043 - val_accuracy: 0.7030
#
# Epoch 00083: val_loss did not improve from 1.40221
# Epoch 84/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2169 - accuracy: 0.9343 - val_loss: 2.3232 - val_accuracy: 0.6969
#
# Epoch 00084: val_loss did not improve from 1.40221
# Epoch 85/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2057 - accuracy: 0.9407 - val_loss: 2.1397 - val_accuracy: 0.6842
#
# Epoch 00085: val_loss did not improve from 1.40221
# Epoch 86/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2078 - accuracy: 0.9381 - val_loss: 2.1601 - val_accuracy: 0.6868
#
# Epoch 00086: val_loss did not improve from 1.40221
# Epoch 87/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2258 - accuracy: 0.9297 - val_loss: 2.3676 - val_accuracy: 0.7056
#
# Epoch 00087: val_loss did not improve from 1.40221
# Epoch 88/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2112 - accuracy: 0.9366 - val_loss: 2.3692 - val_accuracy: 0.6925
#
# Epoch 00088: val_loss did not improve from 1.40221
# Epoch 89/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2183 - accuracy: 0.9385 - val_loss: 2.3973 - val_accuracy: 0.6973
#
# Epoch 00089: val_loss did not improve from 1.40221
# Epoch 90/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2380 - accuracy: 0.9319 - val_loss: 2.2035 - val_accuracy: 0.6899
#
# Epoch 00090: val_loss did not improve from 1.40221
# Epoch 91/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1915 - accuracy: 0.9436 - val_loss: 2.2132 - val_accuracy: 0.6955
#
# Epoch 00091: val_loss did not improve from 1.40221
# Epoch 92/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2201 - accuracy: 0.9343 - val_loss: 2.0628 - val_accuracy: 0.6995
#
# Epoch 00092: val_loss did not improve from 1.40221
# Epoch 93/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2295 - accuracy: 0.9335 - val_loss: 2.1735 - val_accuracy: 0.6837
#
# Epoch 00093: val_loss did not improve from 1.40221
# Epoch 94/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2162 - accuracy: 0.9346 - val_loss: 2.3343 - val_accuracy: 0.6859
#
# Epoch 00094: val_loss did not improve from 1.40221
# Epoch 95/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2066 - accuracy: 0.9423 - val_loss: 2.1787 - val_accuracy: 0.6951
#
# Epoch 00095: val_loss did not improve from 1.40221
# Epoch 96/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2069 - accuracy: 0.9382 - val_loss: 2.2606 - val_accuracy: 0.6977
#
# Epoch 00096: val_loss did not improve from 1.40221
# Epoch 97/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1806 - accuracy: 0.9427 - val_loss: 2.4913 - val_accuracy: 0.6785
#
# Epoch 00097: val_loss did not improve from 1.40221
# Epoch 98/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2341 - accuracy: 0.9334 - val_loss: 2.2410 - val_accuracy: 0.6833
#
# Epoch 00098: val_loss did not improve from 1.40221
# Epoch 99/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2043 - accuracy: 0.9420 - val_loss: 2.4207 - val_accuracy: 0.6877
#
# Epoch 00099: val_loss did not improve from 1.40221
# Epoch 100/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1990 - accuracy: 0.9436 - val_loss: 2.5228 - val_accuracy: 0.6964
#
# Epoch 00100: val_loss did not improve from 1.40221
# Epoch 101/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1871 - accuracy: 0.9442 - val_loss: 2.5388 - val_accuracy: 0.6837
#
# Epoch 00101: val_loss did not improve from 1.40221
# Epoch 102/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2012 - accuracy: 0.9431 - val_loss: 2.3796 - val_accuracy: 0.6833
#
# Epoch 00102: val_loss did not improve from 1.40221
# Epoch 103/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2372 - accuracy: 0.9279 - val_loss: 2.4647 - val_accuracy: 0.6964
#
# Epoch 00103: val_loss did not improve from 1.40221
# Epoch 104/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1808 - accuracy: 0.9481 - val_loss: 2.3320 - val_accuracy: 0.6903
#
# Epoch 00104: val_loss did not improve from 1.40221
# Epoch 105/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2206 - accuracy: 0.9361 - val_loss: 2.5353 - val_accuracy: 0.6977
#
# Epoch 00105: val_loss did not improve from 1.40221
# Epoch 106/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1982 - accuracy: 0.9438 - val_loss: 2.2727 - val_accuracy: 0.6986
#
# Epoch 00106: val_loss did not improve from 1.40221
# Epoch 107/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1976 - accuracy: 0.9371 - val_loss: 2.3796 - val_accuracy: 0.6934
#
# Epoch 00107: val_loss did not improve from 1.40221
# Epoch 108/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1986 - accuracy: 0.9399 - val_loss: 2.3638 - val_accuracy: 0.6850
#
# Epoch 00108: val_loss did not improve from 1.40221
# Epoch 109/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.1889 - accuracy: 0.9440 - val_loss: 2.7162 - val_accuracy: 0.6868
#
# Epoch 00109: val_loss did not improve from 1.40221
# Epoch 110/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2187 - accuracy: 0.9386 - val_loss: 2.4728 - val_accuracy: 0.6938
#
# Epoch 00110: val_loss did not improve from 1.40221
# Epoch 111/1000
# 215/215 [==============================] - 1s 6ms/step - loss: 0.2259 - accuracy: 0.9353 - val_loss: 2.4784 - val_accuracy: 0.6864
#
# Epoch 00111: val_loss did not improve from 1.40221

# %%
best_model = load_model('models/11-1.4022126197814941.hdf5')

# %%
score = best_model.evaluate(X_test, y_test)
print(f'손실 : {score[0]}')
print(f'정확도 : {score[1]}')
# Out:
# 72/72 [==============================] - 0s 3ms/step - loss: 1.4022 - accuracy: 0.6741
# 손실 : 1.4022126197814941
# 정확도 : 0.6741032600402832
